# %%
from pathlib import Path
from fastai.vision import *

# %%
def _flip_lr(x):
    "Flip `x` horizontally."
    return x.flip(2)
flip_lr = TfmPixel(_flip_lr)

# %%
def _crop(x):
    print(x.shape)
    return x[:, 32, 32]
my_crop = TfmPixel(_crop)

# %%
tfms
# Out:
# ([RandTransform(tfm=TfmCrop (crop_pad), kwargs={'row_pct': (0, 1), 'col_pct': (0, 1), 'padding_mode': 'reflection'}, p=1.0, resolved={'row_pct': 0.19568378078420545, 'col_pct': 0.9709520297189015, 'padding_mode': 'reflection'}, do_run=True, is_random=True, use_on_y=True),
#   RandTransform(tfm=TfmPixel (flip_lr), kwargs={}, p=0.5, resolved={}, do_run=True, is_random=True, use_on_y=True),
#   RandTransform(tfm=TfmCoord (symmetric_warp), kwargs={'magnitude': (-0.2, 0.2)}, p=0.75, resolved={'magnitude': tensor([ 0.1950,  0.1355, -0.0904,  0.1501]), 'invert': False}, do_run=True, is_random=True, use_on_y=True),
#   RandTransform(tfm=TfmAffine (rotate), kwargs={'degrees': (-10.0, 10.0)}, p=0.75, resolved={'degrees': -8.588140634180263}, do_run=True, is_random=True, use_on_y=True),
# ...

# %%
tfms = get_transforms(xtra_tfms=[my_crop()])

def get_ex(): return open_image('/data2/datasets/clobotics/ccth/images/cropped/versions/train20200129_val20200117_test20191122/for-image-quality-model/round1/good/1037551/8c0aae77071a17c419f6dc8f01968259_47_1037551.jpg')

def plots_f(rows, cols, width, height, **kwargs):
    [get_ex().apply_tfms([my_crop()], **kwargs).show(ax=ax) for i,ax in enumerate(plt.subplots(
        rows,cols,figsize=(width, height))[1].flatten())]

# %%
plots_f(2, 4, 12, 6, size=224, resize_method=ResizeMethod.PAD, padding_mode='zeros')
# Out:
# torch.Size([3, 224, 60])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-45-d57c0b672f23> in <module>
# ----> 1 plots_f(2, 4, 12, 6, size=224, resize_method=ResizeMethod.PAD, padding_mode='zeros')
#
# <ipython-input-44-022e280239d7> in plots_f(rows, cols, width, height, **kwargs)
#       5 def plots_f(rows, cols, width, height, **kwargs):
#       6     [get_ex().apply_tfms([my_crop()], **kwargs).show(ax=ax) for i,ax in enumerate(plt.subplots(
# ----> 7         rows,cols,figsize=(width, height))[1].flatten())]
#
# <ipython-input-44-022e280239d7> in <listcomp>(.0)
#       4
#       5 def plots_f(rows, cols, width, height, **kwargs):
# ----> 6     [get_ex().apply_tfms([my_crop()], **kwargs).show(ax=ax) for i,ax in enumerate(plt.subplots(
#       7         rows,cols,figsize=(width, height))[1].flatten())]
#
# ...
